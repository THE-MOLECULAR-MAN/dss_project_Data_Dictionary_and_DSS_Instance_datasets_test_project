# %%
import logging
import re
from typing import List, Dict, Optional
from urllib.parse import urljoin

import dataiku
import pandas as pd
import requests
from bs4 import BeautifulSoup
from dateutil import parser as date_parser

# -----------------------------------------------------------------------------
# Configuration
# -----------------------------------------------------------------------------
TARGET_URL = "https://cdn.downloads.dataiku.com/public/dss-plugins/"
OUTPUT_DATASET_NAME = "store_plugin_ids_and_dss_versions"
USER_AGENT = "DataikuDSS/14.2 (Scraping Recipe)"

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger(__name__)

# -----------------------------------------------------------------------------
# Core Scraping Logic
# -----------------------------------------------------------------------------

class PluginDirectoryScraper:
    """
    Encapsulates logic to scrape the Dataiku CDN open directory for plugins.
    """
    def __init__(self, base_url: str):
        self.base_url = base_url
        self.session = requests.Session()
        self.session.headers.update({"User-Agent": USER_AGENT})

    def _get_soup(self, url: str) -> Optional[BeautifulSoup]:
        """Fetches a URL and returns a BeautifulSoup object."""
        try:
            response = self.session.get(url, timeout=10)
            response.raise_for_status()
            return BeautifulSoup(response.text, "html.parser")
        except requests.RequestException as e:
            logger.error(f"Failed to fetch {url}: {e}")
            return None

    def _is_valid_link(self, href: str, text: str) -> bool:
        """Filters out parent directory links and query parameters."""
        if not href or href.startswith("?") or href.startswith("/") or "Parent Directory" in text:
            return False
        return True

    def _parse_directory_row(self, row_text: str) -> Optional[str]:
        """
        Attempts to extract a date string from the text row of a directory listing.
        Standard Apache/Nginx listings usually look like: 'Name  Last modified  Size'
        """
        # Heuristic: Look for patterns resembling dates (YYYY-MM-DD or DD-Mon-YYYY)
        # This regex looks for common date starts to split the string
        date_match = re.search(r'(\d{4}-\d{2}-\d{2}|\d{2}-[a-zA-Z]{3}-\d{4})', row_text)
        if date_match:
            # Extract a chunk of text starting from the date match
            return row_text[date_match.start():].strip().split('  ')[0]
        return None

    def get_plugin_list(self) -> List[str]:
        """Scrapes the root URL for a list of plugin IDs (sub-directories)."""
        soup = self._get_soup(self.base_url)
        if not soup:
            return []

        plugins = []
        # In open directories, links are usually followed by '/'
        for link in soup.find_all("a"):
            href = link.get("href")
            text = link.text
            
            if self._is_valid_link(href, text) and href.endswith("/"):
                # Remove trailing slash to get ID
                plugins.append(href.strip("/"))
        
        return plugins

    def get_versions_for_plugin(self, plugin_id: str) -> List[Dict]:
        """
        Visits a specific plugin page and extracts version and date info.
        Assumes structure: root -> plugin_id -> version_link
        """
        plugin_url = urljoin(self.base_url, f"{plugin_id}/")
        soup = self._get_soup(plugin_url)
        if not soup:
            return []

        versions = []
        
        # Open directory listings are often within <pre> tags or <table> rows
        # We iterate over 'a' tags, then look at the surrounding text or next sibling for the date
        for link in soup.find_all("a"):
            href = link.get("href")
            text = link.text

            if not self._is_valid_link(href, text):
                continue

            # version_number is typically the link text (e.g., "1.0.0/" or "plugin.zip")
            # We strip trailing slashes for clean version numbers
            version_number = href.strip("/")
            
            # Attempt to find the date. 
            # In simple HTML listings, the date is often the text node immediately following the <a> tag
            date_str = None
            
            # Strategy 1: Next sibling text (common in standard Apache indexes)
            if link.next_sibling and isinstance(link.next_sibling, str):
                raw_text = link.next_sibling.strip()
                date_str = self._parse_directory_row(raw_text)
            
            # Strategy 2: If inside a table (common in Nginx/custom indexes), look at the next <td>
            if not date_str:
                parent_td = link.find_parent("td")
                if parent_td:
                    next_td = parent_td.find_next_sibling("td")
                    if next_td:
                        date_str = next_td.text.strip()

            # Parse the date object
            parsed_date = None
            if date_str:
                try:
                    parsed_date = date_parser.parse(date_str)
                except Exception:
                    pass

            versions.append({
                "plugin-id": plugin_id,
                "dss-version-number": version_number,
                "last_modified": parsed_date
            })

        return versions

    def run(self) -> pd.DataFrame:
        """Main execution method."""
        logger.info(f"Starting scrape of {self.base_url}")
        all_data = []
        
        plugin_ids = self.get_plugin_list()
        logger.info(f"Found {len(plugin_ids)} plugins.")

        for pid in plugin_ids:
            # Recursive visit
            versions = self.get_versions_for_plugin(pid)
            all_data.extend(versions)
            logger.debug(f"Scraped {len(versions)} versions for {pid}")

        df = pd.DataFrame(all_data)
        return df

# -----------------------------------------------------------------------------
# Dataiku Integration
# -----------------------------------------------------------------------------

def save_to_dss(df: pd.DataFrame, dataset_name: str):
    """
    Saves a pandas DataFrame to a Dataiku Dataset.
    Idempotent: Creates dataset if it doesn't exist, overwrites if it does.
    """
    client = dataiku.api_client()
    project = client.get_default_project()
    
    # 1. Create or Get Dataset definition
    # We check if it exists in the project list
    dataset_exists = any(d['name'] == dataset_name for d in project.list_datasets())
    
    if not dataset_exists:
        logger.info(f"Creating new dataset: {dataset_name}")
        project.create_dataset(
            dataset_name, 
            type='Local',  # Or 'Filesystem', depending on connection availability
            params={'path': f'${{projectKey}}/{dataset_name}'},
            formatType='csv',
            formatParams={'separator': ',', 'style': 'excel'}
        )
    
    # 2. Write Data
    logger.info(f"Writing {len(df)} rows to {dataset_name}")
    
    # Using the handle directly is the standard way to write DF in recipes
    dss_dataset = dataiku.Dataset(dataset_name)
    dss_dataset.write_with_schema(df)
    logger.info("Write complete.")

# -----------------------------------------------------------------------------
# Main Entry Point
# -----------------------------------------------------------------------------

def main():
    scraper = PluginDirectoryScraper(TARGET_URL)
    df_plugins = scraper.run()
    
    if not df_plugins.empty:
        # Ensure dates are stored as standard strings or datetime objects compatible with DSS
        if "last_modified" in df_plugins.columns:
            df_plugins["last_modified"] = pd.to_datetime(df_plugins["last_modified"])
            
        save_to_dss(df_plugins, OUTPUT_DATASET_NAME)
    else:
        logger.warning("No data found during scrape.")

if __name__ == "__main__":
    main()
