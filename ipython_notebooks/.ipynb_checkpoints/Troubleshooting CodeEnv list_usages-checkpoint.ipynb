# %%
CODE_ENV_NAME = 'INTERNAL_retrieval_augmented_generation_v1'
import dataiku

# Scope: Current Project
client = dataiku.api_client()
# project = client.get_default_project()

code_env_handle = client.get_code_env(CODE_ENV_NAME)

# %%
code_env_handle.list_usages()
